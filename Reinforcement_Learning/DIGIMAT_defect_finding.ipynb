# %% [markdown]
# <a href="https://colab.research.google.com/github/dalexa10/Python_Data_Science/blob/main/Reinforcement_Learning/DIGIMAT_defect_finding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to identify point defects in atomic resolution STEM images with deep learning
#
# Prepared by Chia-Hao Lee
#
# Email: chiahao3@illinois.edu
#
# In this notebook, you'll learn to do the followings:
#
#
#
# 1.   Import atomic resolution STEM images with point defects
# 2.   Use deep learning models to identify defect positions
# 3.   Crop the defect images using the identified defect positions
#
# See more details of these contents from our [Nano Lett paper](https://pubs.acs.org/doi/10.1021/acs.nanolett.0c00269) :
#
# "Deep Learning Enabled Strain Mapping of Single-Atom Defects in Two-Dimensional Transition Metal Dichalcogenides with Sub-Picometer Precision"
#
# Or just visit our [Github repo](https://github.com/ClarkResearchGroup/stem-learning)

# %% [markdown]
# # 1. Download files

# %%
### Use zip files to download and extract the whole folders
# download_link for Google drive "https://drive.google.com/file/d/1GNb9zsnzZOLyi_PvF2X6jydoc5sa6FGt" 

# Use Googledrive to download the files
# !gdown --id 1GNb9zsnzZOLyi_PvF2X6jydoc5sa6FGt

# Uncomment the following line by removing '#' to use dropbox instead
#!wget -O resources.zip https://www.dropbox.com/s/hxoiiibl68q78mv/resources.zip?dl=0

# !unzip -o resources.zip
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1GNb9zsnzZOLyi_PvF2X6jydoc5sa6FGt
# To: /content/resources.zip
# 100% 21.0M/21.0M [00:00<00:00, 65.8MB/s]
# Archive:  resources.zip
#   inflating: image_parse.py
#   inflating: model_2Te.json
#   inflating: model_SV.json
#   inflating: RR_2143 STEM 4.6 Mx HAADF_25.1pA_1024px_2.0us_Raw_Stack_16bit.tif
#   inflating: stitcher_py3.py
#   inflating: weights_2Te.h5
#   inflating: weights_SV.h5

# %% [markdown]
# # 2. Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from image_parse import *
from stitcher_py3 import *

# %% [markdown]
# # 3. Import STEM image

# %%
img = imread('RR_2143 STEM 4.6 Mx HAADF_25.1pA_1024px_2.0us_Raw_Stack_16bit.tif')
figsize = (12,12)
plt.figure(figsize=figsize)
plt.imshow(img, cmap='gray')
plt.colorbar()
plt.show()

print("Image shape = %s, min = %.01f, max = %.01f, mean = %.01f, std = %.01f" %(np.shape(img), np.min(img), np.max(img), np.mean(img), np.std(img)))
# Out:
# <ipython-input-3-6a85bcef04f9>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imread('RR_2143 STEM 4.6 Mx HAADF_25.1pA_1024px_2.0us_Raw_Stack_16bit.tif')
# Image shape = (1024, 1024), min = 2736.0, max = 20639.0, mean = 8418.5, std = 1988.8

# %% [markdown]
# # 4. Use deep learning to identify point defects
#
# The model we're using here is called "convolution neural network". The basic working steps are as followed:
#
# 1. Load the model structure and the corresponding weights (parameters)
# 2. Standardize the input image by shifting mean to 0 and scaling std to 1
# 3. Cut the input image into small chunks of (256, 256) with a stride of (64, 64), this makes the model focus on the relevant region while detecting defects instead of processing the entire image at once
# 4. Feed these small image chunks into the model one by one and get the output (prediction). Note that the output has the same size as input as (256, 256)
# 5. Stitch the predictions into the original size as our input image, this is our final output (the model-predicted defect positions of the input image)
# 6. Save the final output

# %%
# Setup DL processing parameters
avg = True
(size_x, size_y, nb_classes) = (1024,1024,2)
(sx, sy) = (64, 64) # The stride of each cropped region
(lx, ly) = (256, 256) # The length of each cropped window

model_list = ["model_2Te.json",
        "model_SV.json"]

weights_list = ["weights_2Te.h5",
         "weights_SV.h5"]

prefix_list = ["01_2Te",
        "02_SV"]

# %%
tStart = time.time()
'''
Load models and weights
'''
prediction_list=[]
for idx, model_fn in enumerate(model_list):
    
    model_weights_fn = weights_list[idx]
    
    print("loading model = ", model_fn)
    model = model_load(model_fn, model_weights_fn)
    
    '''
    Load image
    '''
    t_start = time.time()
    print("Processing STEM image")
    input_img = process_image(img, standardize = True)
    
    print("cutting data")
    tc0 = time.time()
    input_cuts = cut_data(input_img, lx, ly, (sx, sy))
    input_cuts = np.reshape(input_cuts, [-1, lx, ly, 1])
    num_cuts = len(input_cuts)
    tc1 = time.time()
    print("It cost ", tc1-tc0, "sec to cut!")

    print("predicting data")
    tp0 = time.time()
    predictions=[get_avg_pred(model,cut) for cut in input_cuts] if avg else predict(model,input_cuts)
    predictions = np.reshape(np.array(predictions), [num_cuts, lx, ly, nb_classes])
    tp1 = time.time()
    print("It cost ", tp1-tp0, "sec to predict!")

    print("stitching data")
    ts0 = time.time()
    as_stitched = stitch(size_x, size_y, sx, sy, predictions)
    arg_stitched = np.argmax(as_stitched, axis=2)
    ts1 = time.time()
    print("It cost ", ts1-ts0, "sec to stitch!")

    output_prediction = np.uint8(arg_stitched*255)
    print("saving data")
    imsave(prefix_list[idx] + "_prediction.tif", output_prediction)
    t_end = time.time()
    print("Data saved! It cost ", t_end-t_start, "sec!\n")
    prediction_list.append(output_prediction)

tEnd = time.time()
print("All done, congratulations! It took ", tEnd-tStart, "sec in total!")
# Out:
# loading model =  model_2Te.json
# Processing STEM image
# cutting data
# It cost  0.02749037742614746 sec to cut!
# predicting data
# It cost  17.82351064682007 sec to predict!
# stitching data
# It cost  5.066793441772461 sec to stitch!
# saving data
# Data saved! It cost  22.94021987915039 sec!
#
# loading model =  model_SV.json
# <ipython-input-5-47651e7098ff>:44: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave(prefix_list[idx] + "_prediction.tif", output_prediction)
# Processing STEM image
# cutting data
# It cost  0.029057025909423828 sec to cut!
# predicting data
# It cost  9.772151231765747 sec to predict!
# stitching data
# It cost  4.054423809051514 sec to stitch!
# saving data
# Data saved! It cost  13.87588095664978 sec!
#
# All done, congratulations! It took  41.998966693878174 sec in total!

# %%
# Visualize the final output of the convolution neural network

figsize = (12,12)
plt.figure(figsize=figsize)
plt.imshow(prediction_list[1], cmap='gray') #Change to prediction_list[0] to see the 2Te result
plt.colorbar()
plt.show()

# %% [markdown]
# # 5. Get defect coordinates

# %%
def circle_detect(img):
  from skimage.measure import regionprops
  from scipy import ndimage as ndi

  location_list = []
  (width, height) = np.shape(img)
 
  label_objects, nb_labels = ndi.label(img)
  props = regionprops(label_objects)

  ori_array = np.array(img)
  for p in props:
    if p.area >= 10:
      c_y, c_x = p.centroid
      location_list.append((int(c_y), int(c_x)))
  return location_list

# %%
location_list_2Te = circle_detect(prediction_list[0])
location_list_SV = circle_detect(prediction_list[1])
print("2Te, ", np.shape(location_list_2Te))
print("SV, ", np.shape(location_list_SV))
# Out:
# 2Te,  (123, 2)
# SV,  (283, 2)

# %%
# Save the defect positions into an image

map_2Te = np.zeros_like(img)
for pos in location_list_2Te:
  map_2Te[pos] = 65535
imsave("map_2Te.tif", map_2Te)

map_SV = np.zeros_like(img)
for pos in location_list_SV:
  map_SV[pos] = 65535
imsave("map_SV.tif", map_SV)
# Out:
# <ipython-input-9-fcf36ab7bae4>:6: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave("map_2Te.tif", map_2Te)
# <ipython-input-9-fcf36ab7bae4>:11: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave("map_SV.tif", map_SV)

# %% [markdown]
# # 6. Crop defects

# %%
def make_mask_from_positions(position_list, radius, data_shape):
    def make_square_mask(centerX, centerY, imageSizeX, imageSizeY, radius):
        y, x = np.ogrid[-centerX:imageSizeX-centerX, -centerY:imageSizeY-centerY]
        mask = np.logical_and(np.abs(y)<=radius, np.abs(x)<=radius)
        return mask

    mask = np.zeros(data_shape, dtype=np.bool)
    for position in position_list:
        mask += make_square_mask(
                position[0], position[1],
                data_shape[0], data_shape[1],
                radius)
    return mask

def num_defects_in_window(center_list, l):
    num_defects_list = []

    for (i, j) in center_list:
        x_start = i - l//2 
        x_end   = i + l//2 + l%2 
        y_start = j - l//2
        y_end   = j + l//2 + l%2
        num_defects = sum(map(lambda r: x_start < r[0] < x_end and y_start < r[1] < y_end, list(center_list)))
        num_defects_list.append(num_defects)
    return num_defects_list

def crop_Image(image, center_list, size, offset):
    img_list=[]
    crop_positions_list=[]
    for (x, y) in center_list:
        x_start = x - size[0]//2 + offset[0]
        x_end   = x + size[0]//2 + offset[0] + size[0]%2 
        y_start = y - size[1]//2 + offset[1]
        y_end   = y + size[1]//2 + offset[1] + size[1]%2
        if 0 <= x_start < x_end < np.shape(image)[0] and 0 <= y_start < y_end < np.shape(image)[1]: 
            img_list.append(image[x_start:x_end, y_start:y_end])
            crop_positions_list.append((x,y))
    return img_list, crop_positions_list

# %%
### Setup the cropping parameters and crop the defects from the original image using the identified defect positions

defect_mode = 'defect'

# Setup the cropping parameter
# This parameter is to eliminate the defect sites that are surrounded by other types of influencing defect (like 2Te)
# So the larger the parameter, the farther defects are included in the calculation of masking.
if defect_mode == 'defect':
    elimination_radius = 32 # Radius of the box, so the window size will be (2 * eliminator_radius)^2, 64*64 will be 4*4 unit cells
elif defect_mode == 'regular': # This code can also cut the non-defect region, you just need to feed all the chalcogen sites and use the defect positions to select those unaffected sites. 
    elimination_radius = 64 

NN_window = elimination_radius*2
crop_size = [128,128]
offset = [0,0]
total_defect_count = 0
total_crop_count = 0
count = 0
total_img_list=[]

# Importing images
quant_img = img
defect_img = map_SV # Swap the map_SV and map_2Te to see the results of 2Te
eliminate_map_img = map_2Te

# Find defect positions and mask positions
defect_positions = np.transpose(np.nonzero(defect_img))
mask_positions = np.transpose(np.nonzero(eliminate_map_img))
print('Find ', len(defect_positions), 'defects from original defect map')
print('Find ', len(mask_positions), 'defects from eliminate map ')

# Apply mask and find defect positions again
mask = ~make_mask_from_positions(mask_positions, elimination_radius, np.shape(defect_img))
elim_defect_positions = np.transpose(np.nonzero(mask*defect_img))
print('Find ', len(elim_defect_positions), 'defects after elimination from eliminate map')

# Process the elim_defect_list and remove those who has NN in the specified window.
num_defects= num_defects_in_window(elim_defect_positions, NN_window)
    
# Get the final defect positions by checking NN numbers
final_defect_positions=[]
for num in range(len(num_defects)):
    if defect_mode =='regular': # For Regular (defectless) case there's no need for NN elimination
        if num_defects[num] >= 1:
            final_defect_positions.append(elim_defect_positions[num])
    else:
        if num_defects[num] == 1:
            final_defect_positions.append(elim_defect_positions[num])

total_defect_count += len(final_defect_positions)
print('Find ', len(final_defect_positions), 'defects after elimination from NN')

# Crop final images
final_img_list = []
crop_positions_list = []
final_img_list, crop_positions_list = crop_Image(quant_img, final_defect_positions, crop_size, offset)
print('Crop', len(final_img_list), 'defects after considering image edges')
total_crop_count += len(final_img_list)

# Save final image stack for each image
for i in range(len(final_img_list)):
    count += 1
    total_img_list.append(final_img_list[i])
# total_img_list = All the image stacks together
print('\nTotal defects number are ', total_defect_count)    
print('\nElimination radius = ', elimination_radius)
print('NN_window = ', NN_window)
print('Total cropped images number are ', total_crop_count) 

# Save the final stack
output_fn = defect_mode + '_stack_'+str(len(total_img_list)).zfill(5)+'_NN'+str(NN_window)+'.tif'
print('"', output_fn, '" has been saved!')
imsave(output_fn, np.uint16(np.array(total_img_list)))
# Out:
# Find  283 defects from original defect map
# Find  123 defects from eliminate map
# Find  191 defects after elimination from eliminate map
# Find  63 defects after elimination from NN
# Crop 46 defects after considering image edges
#
# Total defects number are  63
#
# Elimination radius =  32
# NN_window =  64
# Total cropped images number are  46
# " defect_stack_00046_NN64.tif " has been saved!
# <ipython-input-10-91a611e9848c>:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros(data_shape, dtype=np.bool)
# <ipython-input-19-0f92259c3b6d>:73: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave(output_fn, np.uint16(np.array(total_img_list)))

# %%
### Visualize the cropped defect images

# Check cropped images
plt.figure()
plt.title('Cropped image')
plt.imshow(total_img_list[0])
plt.show()

# Check direct sum image
'''
Note that this is just a direct sum, a better way to do this is to perform image registration for sub-px accuracy
'''
plt.figure()
plt.title('Direct sum of the cropped images')
plt.imshow(np.sum(total_img_list, axis=0))
plt.show()

# %%
# Sanity check of the defect position at each step
(x,y)=zip(*defect_positions)        # Original defect position
(x_d,y_d)=zip(*mask_positions)       # Mask coming from other nearby defects (different types)
(x_e,y_e)=zip(*elim_defect_positions)    # Remained positions after the above masking
(x_f,y_f)=zip(*final_defect_positions)   # Final positions after NN removal
(x_c,y_c)=zip(*crop_positions_list)     # Crop positions list considering the image edges

plt.figure(figsize=(8,8))
plt.scatter(y,x,s=1)            #Blue, original defect position
plt.scatter(y_d,x_d, s=3)         #Orange, nearby defects
plt.scatter(y_e,x_e,s=5)          #Green
plt.scatter(y_f,x_f,s=10)         #Red
plt.scatter(y_c,x_c,s=15)         #Purple, final cropping position

plt.gca().invert_yaxis()
# plt.axes().set_aspect('equal')
plt.show()

# %% [markdown]
# ###Results
# #### Part A
# Note that for the SV deffects, the following timing data were obtained
#
# Processing STEM image \\
# cutting data \\
# It cost  0.029057025909423828 sec to cut! \\
# predicting data \\
# It cost  9.772151231765747 sec to predict! \\
# stitching data \\
# It cost  4.054423809051514 sec to stitch! \\
# saving data
# Data saved! **It cost  13.87588095664978 sec!**

# %% [markdown]
# ####Part B & C
# It is clear that using a deep learning model with sufficient data to first be trainned it and then, as a predictor tool is much more efficient compared to hand labelind and intensity filtering methods. However, to obtained a good-enough precision deep learning model, it is necessary a considerable amount of label data, that might be required to be evaluated by a human, which can increase the research time and cost. In other words, the former method is well suited for large amount of data
